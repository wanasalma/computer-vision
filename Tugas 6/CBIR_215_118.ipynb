# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import offsetbox
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from sklearn import manifold

class CV_plot_utils:
  # Plot image
  def plot_img(img, range=[0, 255]):
      plt.imshow(img, vmin=range[0], vmax=range[1])
      plt.xlabel("xpixels")
      plt.ylabel("ypixels")
      plt.tight_layout()
      plt.show()
      plt.close()

  # Plots images in 2 rows: top row is query, bottom row is answer
  def plot_query_retrieval(img_query, imgs_retrieval, outFile):
      n_retrieval = len(imgs_retrieval)
      fig = plt.figure(figsize=(2*n_retrieval, 4))
      fig.suptitle("Image Retrieval (k={})".format(n_retrieval), fontsize=25)

      # Plot query image
      ax = plt.subplot(2, n_retrieval, 0 + 1)
      plt.imshow(img_query)
      ax.get_xaxis().set_visible(False)
      ax.get_yaxis().set_visible(False)
      for axis in ['top', 'bottom', 'left', 'right']:
          ax.spines[axis].set_linewidth(4)  # increase border thickness
          ax.spines[axis].set_color('black')  # set to black
      ax.set_title("query",  fontsize=14)  # set subplot title

      # Plot retrieval images
      for i, img in enumerate(imgs_retrieval):
          ax = plt.subplot(2, n_retrieval, n_retrieval + i + 1)
          plt.imshow(img)
          ax.get_xaxis().set_visible(False)
          ax.get_yaxis().set_visible(False)
          for axis in ['top', 'bottom', 'left', 'right']:
              ax.spines[axis].set_linewidth(1)  # set border thickness
              ax.spines[axis].set_color('black')  # set to black
          ax.set_title("Rank #%d" % (i+1), fontsize=14)  # set subplot title

      if outFile is None:
          plt.show()
      else:
          plt.savefig(outFile, bbox_inches='tight')
      plt.close()

  # Plot t-SNE of images
  def plot_tsne(X, imgs, outFile):

      def imscatter(x, y, images, ax=None, zoom=1.0):
          if ax is None:
              ax = plt.gca()
          x, y = np.atleast_1d(x, y)
          artists = []
          for x0, y0, img0 in zip(x, y, images):
              im = OffsetImage(img0, zoom=zoom)
              ab = AnnotationBbox(im, (x0, y0), xycoords='data', frameon=True)
              artists.append(ax.add_artist(ab))
          ax.update_datalim(np.column_stack([x, y]))
          ax.autoscale()
          return artists

      def plot_embedding(X, imgs, title=None):
          x_min, x_max = np.min(X, 0), np.max(X, 0)
          X = (X - x_min) / (x_max - x_min)

          plt.figure()
          ax = plt.subplot(111)
          for i in range(X.shape[0]):
              plt.text(X[i, 0], X[i, 1], ".", fontdict={'weight': 'bold', 'size': 9})
          if hasattr(offsetbox, 'AnnotationBbox'):
              imscatter(X[:,0], X[:,1], imgs, zoom=0.3, ax=ax)

          plt.xticks([]), plt.yticks([])
          if title is not None:
              plt.title(title, fontsize=18)

      tsne = manifold.TSNE(n_components=2, init='pca', random_state=0)
      X_tsne = tsne.fit_transform(X)
      plot_embedding(X_tsne, imgs, "t-SNE embeddings")
      if outFile is None:
          plt.show()
      else:
          plt.savefig(outFile, bbox_inches='tight')
      plt.close()

  # Plot image reconstructions
  def plot_reconstructions(imgs, imgs_reconstruct, outFile,
                          range_imgs=[0, 255],
                          range_imgs_reconstruct=[0, 1]):
      # Create plot to save
      assert len(imgs) == len(imgs_reconstruct)
      fig = plt.figure(figsize=(20, 4))
      fig.suptitle("Image Reconstructions", fontsize=35)
      n = min(len(imgs), 10)
      for i in range(n):

          # Plot original image
          ax = plt.subplot(2, n, i + 1)
          plt.imshow(imgs[i],
                    vmin=range_imgs[0],
                    vmax=range_imgs[1])
          ax.get_xaxis().set_visible(False)
          ax.get_yaxis().set_visible(False)

          # Plot reconstructed image
          ax = plt.subplot(2, n, n + i + 1)
          plt.imshow(imgs_reconstruct[i],
                    vmin=range_imgs_reconstruct[0],
                    vmax=range_imgs_reconstruct[1])
          ax.get_xaxis().set_visible(False)
          ax.get_yaxis().set_visible(False)

      if outFile is None:
          plt.show()
      else:
          plt.savefig(outFile, bbox_inches='tight')
      plt.close()

# %%
import os
import skimage.io
from multiprocessing import Pool

class CV_IO_utils:
  # Read image
  def read_img(filePath):
      return skimage.io.imread(filePath, as_gray=False)

  # Read images with common extensions from a directory
  def read_imgs_dir(dirPath, extensions, parallel=True):
      args = [os.path.join(dirPath, filename)
              for filename in os.listdir(dirPath)
              if any(filename.lower().endswith(ext) for ext in extensions)]
      if parallel:
          pool = Pool()
          imgs = pool.map(CV_IO_utils.read_img, args)
          pool.close()
          pool.join()
      else:
          imgs = [read_img(arg) for arg in args]
      return imgs

  # Save image to file
  def save_img(filePath, img):
      skimage.io.imsave(filePath, img)

# %%
from multiprocessing import Pool
from skimage.transform import resize

# Apply transformations to multiple images
class CV_transform_utils:
    
  def apply_transformer(imgs, transformer, parallel=True):
      if parallel:
          pool = Pool()
          imgs_transform = pool.map(transformer, [img for img in imgs])
          pool.close()
          pool.join()
      else:
          imgs_transform = [transformer(img) for img in imgs]
      return imgs_transform

  # Normalize image data [0, 255] -> [0.0, 1.0]
  def normalize_img(img):
      return img / 255.

  # Resize image
  def resize_img(img, shape_resized):
      img_resized = resize(img, shape_resized,
                          anti_aliasing=True,
                          preserve_range=True)
      assert img_resized.shape == shape_resized
      return img_resized

  # Flatten image
  def flatten_img(img):
      return img.flatten("C")

# %%
import random
import numpy as np

class utils:
    # Get split indices
  def split(fracs, N, seed):
      fracs = [round(frac, 2) for frac in fracs]
      if sum(fracs) != 1.00:
          raise Exception("fracs do not sum to one!")

      # Shuffle ordered indices
      indices = list(range(N))
      random.Random(seed).shuffle(indices)
      indices = np.array(indices, dtype=int)

      # Get numbers per group
      n_fracs = []
      for i in range(len(fracs) - 1):
          n_fracs.append(int(max(fracs[i] * N, 0)))
      n_fracs.append(int(max(N - sum(n_fracs), 0)))

      if sum(n_fracs) != N:
          raise Exception("n_fracs do not sum to N!")

      # Sample indices
      n_selected = 0
      indices_fracs = []
      for n_frac in n_fracs:
          indices_frac = indices[n_selected:n_selected + n_frac]
          indices_fracs.append(indices_frac)
          n_selected += n_frac

      # Check no intersections
      for a, indices_frac_A in enumerate(indices_fracs):
          for b, indices_frac_B in enumerate(indices_fracs):
              if a == b:
                  continue
              if utils.is_intersect(indices_frac_A, indices_frac_B):
                  raise Exception("there are intersections!")

      return indices_fracs

  # Is there intersection?
  def is_intersect(arr1, arr2):
      n_intersect = len(np.intersect1d(arr1, arr2))
      if n_intersect == 0: return False
      else: return True

# %% [markdown]
# # Image Retrieval with 3 models (Simple Auto Encoder, Convolutional Auto Encoder, VGG19)

# %%
import os
import numpy as np
import tensorflow as tf
from sklearn.neighbors import NearestNeighbors
import copy
import sklearn.metrics as metric
from statistics import mean
import re

correct = 0
wrong = 0
loss_ = []
acc_ = []
ground_truth = []
retrieval_labels = []
prec_list = []
rec_list = []

acc_transfer = []
loss_transfer = []
prec_transfer = []
rec_transfer = []


retrieval_label=os.listdir(r"Train/")
truth_label=os.listdir(r"Test/")

# Apply transformations to all images
class ImageTransformer(object):

    def __init__(self, shape_resize):
        self.shape_resize = shape_resize

    def __call__(self, img):
        img_transformed = CV_transform_utils.resize_img(img, self.shape_resize)
        img_transformed = CV_transform_utils.normalize_img(img_transformed)
        return img_transformed

transfer = ['Xception', 'VGG16', 'VGG19', 'ResNet50', 'ResNet101', 
            'ResNet152', 'ResNet50V2', 'ResNet101V2', 'ResNet152V2',
            'InceptionV3', 'InceptionResNetV2', 'MobileNet', 'MobileNetV2',
            'DenseNet121', 'DenseNet169', 'DenseNet201', 'NASNetMobile',
            'NASNetLarge', 'EfficientNetB0', 'EfficientNetB1', 'EfficientNetB2',
            'EfficientNetB3', 'EfficientNetB4', 'EfficientNetB5', 'EfficientNetB6',
            'EfficientNetB7']



# Run mode: (autoencoder -> simpleAE, convAE) or (transfer learning -> vgg19)
modelName = "vgg19"  # try: "simpleAE", "convAE", "vgg19"
trainModel = True
parallel = True  # use multicore processing

# Make paths
dataTrainDir = os.path.join(os.getcwd(), "Train")
dataTestDir = os.path.join(os.getcwd(), "Test")
outDir = os.path.join(os.getcwd(), "output", modelName)
if not os.path.exists(outDir):
    os.makedirs(outDir)

# Read images
extensions = [".jpg", ".jpeg"]
print("Reading train images from '{}'...".format(dataTrainDir))
imgs_train = CV_IO_utils.read_imgs_dir(dataTrainDir, extensions, parallel=parallel)
print("Reading test images from '{}'...".format(dataTestDir))
imgs_test = CV_IO_utils.read_imgs_dir(dataTestDir, extensions, parallel=parallel)
shape_img = imgs_train[0].shape
print("Image shape = {}".format(shape_img))


print("Loading VGG19 pre-trained model...")
model = tf.keras.applications.InceptionResNetV2(weights='imagenet', include_top=False,
                                            input_shape=shape_img)
model.summary()

shape_img_resize = tuple([int(x) for x in model.input.shape[1:]])
input_shape_model = tuple([int(x) for x in model.input.shape[1:]])
output_shape_model = tuple([int(x) for x in model.output.shape[1:]])
n_epochs = None
    # Build models




# Print some model info
print("input_shape_model = {}".format(input_shape_model))
print("output_shape_model = {}".format(output_shape_model))


transformer = ImageTransformer(shape_img_resize)
print("Applying image transformer to training images...")
imgs_train_transformed = CV_transform_utils.apply_transformer(imgs_train, transformer, parallel=parallel)
print("Applying image transformer to test images...")
imgs_test_transformed = CV_transform_utils.apply_transformer(imgs_test, transformer, parallel=parallel)

# Convert images to numpy array
X_train = np.array(imgs_train_transformed).reshape((-1,) + input_shape_model)
X_test = np.array(imgs_test_transformed).reshape((-1,) + input_shape_model)
print(" -> X_train.shape = {}".format(X_train.shape))
print(" -> X_test.shape = {}".format(X_test.shape))




# Create embeddings using model
print("Inferencing embeddings using pre-trained model...")
E_train = model.predict(X_train)
E_train_flatten = E_train.reshape((-1, np.prod(output_shape_model)))
E_test = model.predict(X_test)
E_test_flatten = E_test.reshape((-1, np.prod(output_shape_model)))
print(" -> E_train.shape = {}".format(E_train.shape))
print(" -> E_test.shape = {}".format(E_test.shape))
print(" -> E_train_flatten.shape = {}".format(E_train_flatten.shape))
print(" -> E_test_flatten.shape = {}".format(E_test_flatten.shape))


# Fit kNN model on training images
print("Fitting k-nearest-neighbour model on training images...")
knn = NearestNeighbors(n_neighbors=10, metric="cosine")
knn.fit(E_train_flatten)

# Perform image retrieval on test images
print("Performing image retrieval on test images...")
for i, emb_flatten in enumerate(E_test_flatten):
    _, indices = knn.kneighbors([emb_flatten]) # find k nearest train neighbours
    img_query = imgs_test[i] # query image
    imgs_retrieval = [imgs_train[idx] for idx in indices.flatten()] # retrieval images
    for x in indices.flatten():
      if truth_label[i][:3] in retrieval_label[x]:
        correct = correct + 1
      else:
        wrong = wrong + 1
    loss_.append((wrong/5))
    acc_.append((correct/5))
    correct = 0
    wrong = 0

    # Precision Recall
    for x in indices.flatten():
      ground_truth.append(re.split("(\d.*)", truth_label[i])[0])
      retrieval_labels.append(re.split("(\d.*)", retrieval_label[x])[0])
    
    rec_list.append(metric.recall_score(ground_truth, retrieval_labels, average='weighted'))
    prec_list.append(metric.precision_score(ground_truth, retrieval_labels, average='weighted'))

    ground_truth.clear()
    retrieval_labels.clear()

    outFile = os.path.join(outDir, "{}_retrieval_{}.png".format(modelName, i))
    CV_plot_utils.plot_query_retrieval(img_query, imgs_retrieval, outFile)

print("retrieval accuracy: {}".format(mean(acc_)))
print("retrieval loss: {}".format(mean(loss_)))
print("retrieval precision: {}".format(mean(prec_list)))
print("retrieval recall: {}".format(mean(rec_list)))
# Out:
# Reading train images from '/content/drive/MyDrive/face-lfw/Train'...
# Reading test images from '/content/drive/MyDrive/face-lfw/Test'...
# Image shape = (250, 250, 3)
# Loading VGG19 pre-trained model...
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 250, 250, 3  0           []
#                                 )]
#
#  conv2d_203 (Conv2D)            (None, 124, 124, 32  864         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_203 (Batch  (None, 124, 124, 32  96         ['conv2d_203[0][0]']
#  Normalization)                 )
#
#  activation_203 (Activation)    (None, 124, 124, 32  0           ['batch_normalization_203[0][0]']
#                                 )
#
#  conv2d_204 (Conv2D)            (None, 122, 122, 32  9216        ['activation_203[0][0]']
#                                 )
#
#  batch_normalization_204 (Batch  (None, 122, 122, 32  96         ['conv2d_204[0][0]']
#  Normalization)                 )
#
#  activation_204 (Activation)    (None, 122, 122, 32  0           ['batch_normalization_204[0][0]']
#                                 )
#
#  conv2d_205 (Conv2D)            (None, 122, 122, 64  18432       ['activation_204[0][0]']
#                                 )
#
#  batch_normalization_205 (Batch  (None, 122, 122, 64  192        ['conv2d_205[0][0]']
#  Normalization)                 )
#
#  activation_205 (Activation)    (None, 122, 122, 64  0           ['batch_normalization_205[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 60, 60, 64)  0           ['activation_205[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 60, 60, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_206 (Batch  (None, 60, 60, 80)  240         ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 60, 60, 80)   0           ['batch_normalization_206[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 58, 58, 192)  138240      ['activation_206[0][0]']
#
#  batch_normalization_207 (Batch  (None, 58, 58, 192)  576        ['conv2d_207[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 58, 58, 192)  0           ['batch_normalization_207[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 28, 28, 192)  0          ['activation_207[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 28, 28, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_211 (Batch  (None, 28, 28, 64)  192         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_211[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 28, 28, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 28, 28, 96)   55296       ['activation_211[0][0]']
#
#  batch_normalization_209 (Batch  (None, 28, 28, 48)  144         ['conv2d_209[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 28, 28, 96)  288         ['conv2d_212[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_209[0][0]']
#
#  activation_212 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_212[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 28, 28, 192)  0          ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_208 (Conv2D)            (None, 28, 28, 96)   18432       ['max_pooling2d_5[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 28, 28, 64)   76800       ['activation_209[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 28, 28, 96)   82944       ['activation_212[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 28, 28, 64)   12288       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_208 (Batch  (None, 28, 28, 96)  288         ['conv2d_208[0][0]']
#  Normalization)
#
#  batch_normalization_210 (Batch  (None, 28, 28, 64)  192         ['conv2d_210[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 28, 28, 96)  288         ['conv2d_213[0][0]']
#  Normalization)
#
#  batch_normalization_214 (Batch  (None, 28, 28, 64)  192         ['conv2d_214[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_208[0][0]']
#
#  activation_210 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_210[0][0]']
#
#  activation_213 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_213[0][0]']
#
#  activation_214 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_214[0][0]']
#
#  mixed_5b (Concatenate)         (None, 28, 28, 320)  0           ['activation_208[0][0]',
#                                                                   'activation_210[0][0]',
#                                                                   'activation_213[0][0]',
#                                                                   'activation_214[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 28, 28, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_218 (Batch  (None, 28, 28, 32)  96          ['conv2d_218[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_218[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 28, 28, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_218[0][0]']
#
#  batch_normalization_216 (Batch  (None, 28, 28, 32)  96          ['conv2d_216[0][0]']
#  Normalization)
#
#  batch_normalization_219 (Batch  (None, 28, 28, 48)  144         ['conv2d_219[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_216[0][0]']
#
#  activation_219 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_219[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 28, 28, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_216[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_219[0][0]']
#
#  batch_normalization_215 (Batch  (None, 28, 28, 32)  96          ['conv2d_215[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 28, 28, 32)  96          ['conv2d_217[0][0]']
#  Normalization)
#
#  batch_normalization_220 (Batch  (None, 28, 28, 64)  192         ['conv2d_220[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_215[0][0]']
#
#  activation_217 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_217[0][0]']
#
#  activation_220 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_220[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_215[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'activation_220[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 28, 28, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 28, 28, 320)  0           ['block35_1[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_224 (Batch  (None, 28, 28, 32)  96          ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_224 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_224[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_224[0][0]']
#
#  batch_normalization_222 (Batch  (None, 28, 28, 32)  96          ['conv2d_222[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 28, 28, 48)  144         ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_222[0][0]']
#
#  activation_225 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_225[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_222[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_225[0][0]']
#
#  batch_normalization_221 (Batch  (None, 28, 28, 32)  96          ['conv2d_221[0][0]']
#  Normalization)
#
#  batch_normalization_223 (Batch  (None, 28, 28, 32)  96          ['conv2d_223[0][0]']
#  Normalization)
#
#  batch_normalization_226 (Batch  (None, 28, 28, 64)  192         ['conv2d_226[0][0]']
#  Normalization)
#
#  activation_221 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_221[0][0]']
#
#  activation_223 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_223[0][0]']
#
#  activation_226 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_226[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_221[0][0]',
#                                                                   'activation_223[0][0]',
#                                                                   'activation_226[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 28, 28, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 28, 28, 320)  0           ['block35_2[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_230 (Batch  (None, 28, 28, 32)  96          ['conv2d_230[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_230[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_230[0][0]']
#
#  batch_normalization_228 (Batch  (None, 28, 28, 32)  96          ['conv2d_228[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 28, 28, 48)  144         ['conv2d_231[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_228[0][0]']
#
#  activation_231 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_231[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_228[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_231[0][0]']
#
#  batch_normalization_227 (Batch  (None, 28, 28, 32)  96          ['conv2d_227[0][0]']
#  Normalization)
#
#  batch_normalization_229 (Batch  (None, 28, 28, 32)  96          ['conv2d_229[0][0]']
#  Normalization)
#
#  batch_normalization_232 (Batch  (None, 28, 28, 64)  192         ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_227 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_227[0][0]']
#
#  activation_229 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_229[0][0]']
#
#  activation_232 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_232[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_227[0][0]',
#                                                                   'activation_229[0][0]',
#                                                                   'activation_232[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 28, 28, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 28, 28, 320)  0           ['block35_3[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_236 (Batch  (None, 28, 28, 32)  96          ['conv2d_236[0][0]']
#  Normalization)
#
#  activation_236 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_236[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_236[0][0]']
#
#  batch_normalization_234 (Batch  (None, 28, 28, 32)  96          ['conv2d_234[0][0]']
#  Normalization)
#
#  batch_normalization_237 (Batch  (None, 28, 28, 48)  144         ['conv2d_237[0][0]']
#  Normalization)
#
#  activation_234 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_234[0][0]']
#
#  activation_237 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_237[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_234[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_237[0][0]']
#
#  batch_normalization_233 (Batch  (None, 28, 28, 32)  96          ['conv2d_233[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 28, 28, 32)  96          ['conv2d_235[0][0]']
#  Normalization)
#
#  batch_normalization_238 (Batch  (None, 28, 28, 64)  192         ['conv2d_238[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_233[0][0]']
#
#  activation_235 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_235[0][0]']
#
#  activation_238 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_238[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_233[0][0]',
#                                                                   'activation_235[0][0]',
#                                                                   'activation_238[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 28, 28, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 28, 28, 320)  0           ['block35_4[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_242 (Batch  (None, 28, 28, 32)  96          ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_242[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_242[0][0]']
#
#  batch_normalization_240 (Batch  (None, 28, 28, 32)  96          ['conv2d_240[0][0]']
#  Normalization)
#
#  batch_normalization_243 (Batch  (None, 28, 28, 48)  144         ['conv2d_243[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_240[0][0]']
#
#  activation_243 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_243[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_240[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_243[0][0]']
#
#  batch_normalization_239 (Batch  (None, 28, 28, 32)  96          ['conv2d_239[0][0]']
#  Normalization)
#
#  batch_normalization_241 (Batch  (None, 28, 28, 32)  96          ['conv2d_241[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 28, 28, 64)  192         ['conv2d_244[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_239[0][0]']
#
#  activation_241 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_241[0][0]']
#
#  activation_244 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_244[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_239[0][0]',
#                                                                   'activation_241[0][0]',
#                                                                   'activation_244[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 28, 28, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 28, 28, 320)  0           ['block35_5[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_248 (Batch  (None, 28, 28, 32)  96          ['conv2d_248[0][0]']
#  Normalization)
#
#  activation_248 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_248[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_248[0][0]']
#
#  batch_normalization_246 (Batch  (None, 28, 28, 32)  96          ['conv2d_246[0][0]']
#  Normalization)
#
#  batch_normalization_249 (Batch  (None, 28, 28, 48)  144         ['conv2d_249[0][0]']
#  Normalization)
#
#  activation_246 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_246[0][0]']
#
#  activation_249 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_249[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_246[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_249[0][0]']
#
#  batch_normalization_245 (Batch  (None, 28, 28, 32)  96          ['conv2d_245[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 28, 28, 32)  96          ['conv2d_247[0][0]']
#  Normalization)
#
#  batch_normalization_250 (Batch  (None, 28, 28, 64)  192         ['conv2d_250[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_245[0][0]']
#
#  activation_247 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_247[0][0]']
#
#  activation_250 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_250[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_245[0][0]',
#                                                                   'activation_247[0][0]',
#                                                                   'activation_250[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 28, 28, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 28, 28, 320)  0           ['block35_6[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_254 (Batch  (None, 28, 28, 32)  96          ['conv2d_254[0][0]']
#  Normalization)
#
#  activation_254 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_254[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_254[0][0]']
#
#  batch_normalization_252 (Batch  (None, 28, 28, 32)  96          ['conv2d_252[0][0]']
#  Normalization)
#
#  batch_normalization_255 (Batch  (None, 28, 28, 48)  144         ['conv2d_255[0][0]']
#  Normalization)
#
#  activation_252 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_252[0][0]']
#
#  activation_255 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_255[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_252[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_255[0][0]']
#
#  batch_normalization_251 (Batch  (None, 28, 28, 32)  96          ['conv2d_251[0][0]']
#  Normalization)
#
#  batch_normalization_253 (Batch  (None, 28, 28, 32)  96          ['conv2d_253[0][0]']
#  Normalization)
#
#  batch_normalization_256 (Batch  (None, 28, 28, 64)  192         ['conv2d_256[0][0]']
#  Normalization)
#
#  activation_251 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_251[0][0]']
#
#  activation_253 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_253[0][0]']
#
#  activation_256 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_256[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_251[0][0]',
#                                                                   'activation_253[0][0]',
#                                                                   'activation_256[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 28, 28, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 28, 28, 320)  0           ['block35_7[0][0]']
#
#  conv2d_260 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_260 (Batch  (None, 28, 28, 32)  96          ['conv2d_260[0][0]']
# ...
#  Normalization)
#
#  activation_399 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_399[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 6, 6, 224)    129024      ['activation_399[0][0]']
#
#  batch_normalization_400 (Batch  (None, 6, 6, 224)   672         ['conv2d_400[0][0]']
#  Normalization)
#
#  activation_400 (Activation)    (None, 6, 6, 224)    0           ['batch_normalization_400[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 6, 6, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 6, 6, 256)    172032      ['activation_400[0][0]']
#
#  batch_normalization_398 (Batch  (None, 6, 6, 192)   576         ['conv2d_398[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 6, 6, 256)   768         ['conv2d_401[0][0]']
#  Normalization)
#
#  activation_398 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_398[0][0]']
#
#  activation_401 (Activation)    (None, 6, 6, 256)    0           ['batch_normalization_401[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 6, 6, 448)    0           ['activation_398[0][0]',
#                                                                   'activation_401[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 6, 6, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 6, 6, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 6, 6, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 6, 6, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_403 (Batch  (None, 6, 6, 192)   576         ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_403[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 6, 6, 224)    129024      ['activation_403[0][0]']
#
#  batch_normalization_404 (Batch  (None, 6, 6, 224)   672         ['conv2d_404[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 6, 6, 224)    0           ['batch_normalization_404[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 6, 6, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 6, 6, 256)    172032      ['activation_404[0][0]']
#
#  batch_normalization_402 (Batch  (None, 6, 6, 192)   576         ['conv2d_402[0][0]']
#  Normalization)
#
#  batch_normalization_405 (Batch  (None, 6, 6, 256)   768         ['conv2d_405[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_402[0][0]']
#
#  activation_405 (Activation)    (None, 6, 6, 256)    0           ['batch_normalization_405[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 6, 6, 448)    0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 6, 6, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 6, 6, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 6, 6, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 6, 6, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 6, 6, 1536)   0           ['conv_7b_bn[0][0]']
#
# ==================================================================================================
# Total params: 54,336,736
# Trainable params: 54,276,192
# Non-trainable params: 60,544
# __________________________________________________________________________________________________
# input_shape_model = (250, 250, 3)
# output_shape_model = (6, 6, 1536)
# Applying image transformer to training images...
# Applying image transformer to test images...
#  -> X_train.shape = (282, 250, 250, 3)
#  -> X_test.shape = (20, 250, 250, 3)
# Inferencing embeddings using pre-trained model...
#  -> E_train.shape = (282, 6, 6, 1536)
#  -> E_test.shape = (20, 6, 6, 1536)
#  -> E_train_flatten.shape = (282, 55296)
#  -> E_test_flatten.shape = (20, 55296)
# Fitting k-nearest-neighbour model on training images...
# Performing image retrieval on test images...
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# retrieval accuracy: 0.47000000000000003
# retrieval loss: 1.53
# retrieval precision: 0.75
# retrieval recall: 0.20500000000000002

# %%
from statistics import mean

print("retrieval accuracy :", mean(acc_))
print("retrieval loss :", mean(loss_))
print("retrieval precision :", mean(prec_list))
print("retrieval recall :", mean(rec_list))
# Out:
# retrieval accuracy : 0.24
# retrieval loss : 0.76
# retrieval precision : 0.6
# retrieval recall : 0.2

# %%
print("accuracy metric")
for i in range(len(truth_label)):
  print("label :", truth_label[i].split('_')[0], "=", acc_[i])
# Out:
# accuracy metric
# label : Adrien = 0.6
# label : Abdullah = 0.0
# label : Al = 0.0
# label : Al = 0.0
# label : Albert = 0.2
# label : Ali = 0.2
# label : Alejandro = 0.0
# label : Alvaro = 0.2
# label : Andre = 0.6
# label : Ana = 0.0
# label : Amelie = 0.2
# label : Ana = 0.2
# label : Amelia = 0.2
# label : Angelina = 0.0
# label : Angela = 0.4
# label : Anna = 0.2
# label : Andy = 0.6
# label : Ann = 0.2
# label : Britney = 1.0
# label : Condoleezza = 0.0

# %%
print("precision metric")
for i in range(len(truth_label)):
  print("label :", truth_label[i].split('_')[0], "=", prec_list[i])
# Out:
# precision metric
# label : B49 = 1.0
# label : B20 = 1.0
# label : B9 = 1.0
# label : B2 = 1.0
# label : B15 = 1.0
# label : B47 = 1.0
# label : B24 = 1.0
# label : B26 = 1.0
# label : B6 = 1.0
# label : B21 = 1.0
# label : B13 = 1.0
# label : B44 = 1.0
# label : B35 = 1.0
# label : B14 = 1.0
# label : B29 = 1.0
# label : B23 = 1.0
# label : B4 = 1.0
# label : B48 = 1.0
# label : B7 = 1.0
# label : B36 = 1.0
# label : B39 = 1.0
# label : B33 = 1.0
# label : B30 = 1.0
# label : B50 = 1.0
# label : B46 = 1.0
# label : B28 = 1.0
# label : B25 = 1.0
# label : B17 = 1.0
# label : B31 = 1.0
# label : B32 = 1.0
# label : B19 = 1.0
# label : B40 = 1.0
# label : B10 = 1.0
# label : B11 = 1.0
# label : B34 = 1.0
# label : B41 = 1.0
# label : B12 = 1.0
# label : B5 = 1.0
# label : B22 = 1.0
# label : B3 = 1.0
# label : B18 = 1.0
# label : B42 = 1.0
# label : B16 = 1.0
# label : B45 = 1.0
# label : B38 = 1.0
# label : B37 = 1.0
# label : B1 = 1.0
# label : B27 = 1.0
# label : B43 = 1.0
# label : B8 = 1.0

# %%
print("recall metric")
for i in range(len(truth_label)):
  print("label :", truth_label[i].split('_')[0], "=", rec_list[i])
# Out:
# recall metric
# label : B49 = 1.0
# label : B20 = 1.0
# label : B9 = 1.0
# label : B2 = 1.0
# label : B15 = 0.8
# label : B47 = 0.8
# label : B24 = 1.0
# label : B26 = 1.0
# label : B6 = 1.0
# label : B21 = 1.0
# label : B13 = 0.4
# label : B44 = 1.0
# label : B35 = 1.0
# label : B14 = 0.6
# label : B29 = 0.8
# label : B23 = 0.8
# label : B4 = 1.0
# label : B48 = 1.0
# label : B7 = 1.0
# label : B36 = 1.0
# label : B39 = 1.0
# label : B33 = 0.4
# label : B30 = 1.0
# label : B50 = 1.0
# label : B46 = 1.0
# label : B28 = 0.2
# label : B25 = 1.0
# label : B17 = 1.0
# label : B31 = 1.0
# label : B32 = 1.0
# label : B19 = 1.0
# label : B40 = 0.6
# label : B10 = 0.4
# label : B11 = 0.8
# label : B34 = 0.6
# label : B41 = 1.0
# label : B12 = 0.4
# label : B5 = 1.0
# label : B22 = 1.0
# label : B3 = 1.0
# label : B18 = 1.0
# label : B42 = 1.0
# label : B16 = 0.8
# label : B45 = 1.0
# label : B38 = 1.0
# label : B37 = 1.0
# label : B1 = 1.0
# label : B27 = 1.0
# label : B43 = 1.0
# label : B8 = 1.0
